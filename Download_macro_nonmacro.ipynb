# %% [markdown]
# #### Three SAS Programs
# * Nonmacro program (with a single macro variable) for XPT data download ( 1 file at a time)
# * Nonmacro program (with a single macro variable) for CPT data download ( 1 file at a time)
# * Macro program

# %%
fd = open(r'U:\_Treasure_SAS\Single_CPT_Download.sas')
print(fd.read())
fd.close()
# Out:
# * Single_CPT_Download.sas;
# /************************************************************************************
# * TO DOWNLOAD, UNZIP AND RESTORE a SAS data set from only a single CPORT-created
# * trnsposrt file only one at a time) from the MEPS website
# *
# * Just create a macro variable for the data file you are interested in
# * (%LET file = h206a;)   That's it! There is no macro program involved here.
# *
# * The output files are saved in the WORK folder.
# * CAUTION: Downloaed unzipped/zipped/restored SAS data files will only exist
# * in the current SAS session.
# *
# * Adjust the code as appropriate to save the files permanently.
# *
# * Written by: Pradip Muhuri
# ***************************************************************************************/
#
# proc datasets library=work kill;run;quit;
# %LET file=h206a;
# %put &=file;
# /* use pathname function to get work library's path and store in macro variable wpath */
# %let wpath=%sysfunc(pathname(work));
#
# ...

# %%
fd = open(r'U:\_Treasure_SAS\Single_XPT_Download.sas')
print(fd.read())
fd.close()
# Out:
# * Single_XPT_Download.sas;
# /************************************************************************************
# * TO DOWNLOAD, UNZIP AND RESTORE a SAS data set from only a single XPORT-created
# * trnsposrt file only one at a time) from the MEPS website
# *
# * Just create a macro variable for the data file you are interested in
# * (%LET file = h183;)   That's it! There is no macro program involved here.
# *
# * The output files are saved in the WORK folder.
# * CAUTION: Downloaed unzipped/zipped/restored SAS data files will only exist
# * in the current SAS session.
# *
# * Adjust the code as appropriate to save the files permanently.
# *
# * Written by: Pradip Muhuri
# ***************************************************************************************/
#
# proc datasets library=work kill;run;quit;
# %LET file=h183;
# %put &=file;
# /* use pathname function to get work library's path and store in macro variable wpath */
# %let wpath=%sysfunc(pathname(work));
#
# ...

# %%
fd = open(r'U:\_Treasure_SAS\Automate_Load_Oct06_rev.sas')
print(fd.read())
fd.close()
# Out:
# *Automate_Load_Oct06_rev.sas;
# /***********************************************************************
# This program  automates:
# - downloading of zipped SAS Trasport files from the MEPS website
# - unzipping of those files (created by XPORT Engine vs. PROC CPORT)
# - restoring to SAS data sets
#
# Written by: Pradip Muhuri - Revised 10/06/2020
# Acknowledgements: Thanks to SAS(R) Institute for providing technical support
# to the revision/expansion of the original program.
# ************************************************************************/
# options  nosymbolgen nomlogic nomprint; /* Options may be turned on when needed */
#
# /**************************************************************************
# * The following two statements delete the existing files in the libraries  *
# * specified. The user has the option to delete or comment out them        *            *
# ***************************************************************************/
# ...
